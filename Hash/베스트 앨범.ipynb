# %%
def solution(genres, plays):
    answer=[]
    a = set(genres)
    dic={}
    for i in a:
        dic[i]=[]
    for key,value in zip(genres,plays):
        dic[key].append(value)
    dic = sorted(dic.items(),key=lambda x : sum(x[1]),reverse=True)
    lis= []
    for i in dic:
        if len(i[1])<2:
          print(i[1][0])
          answer.append(play.index(i[1][0]))
        else:
            for j in sorted(i[1],reverse=True)[:2]:
              
                
                answer.append(plays.index(j))
    return answer

# %%
genres=["classic", "pop", "classic", "classic", "pop"]
plays=[500, 600, 150, 800, 2500]

# %%
solution(genres, plays)
# Out:
# 2500
# 600
# 800
# 500
# [4, 1, 3, 0]

# %%
print(dic)
# Out:
# [('pop', [2500, 600]), ('classic', [800, 500, 150])]

# %%
b = [1,2,3,3]

# %%
b.index(3)
# Out:
# 2
