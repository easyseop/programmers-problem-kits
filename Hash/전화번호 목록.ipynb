# %%
def solution(phone_book):
    answer=True
    pb=sorted(set(phone_book))
    for i in range(0,len(pb)-1):
        if pb[i]== pb[i+1][:len(pb[i])]:
            answer=False
            break
        
    return answer
